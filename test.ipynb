# %%
from zmq.sugar import device

x = 10
y = 3.14
nome = "sensore"
x,y,nome
# Out:
# (10, 3.14, 'sensore')

# %% [markdown]
# # Tupla

# %%
coordinate = (45.12,9.15) #tuple tonde (immutabile)
coordinate

# %% [markdown]
# # Liste

# %%
valori=[1,2,3] #lista (modificabile)
valori.append(4)
valori

# %% [markdown]
# # Operazioni su stringhe

# %%
msg = "sensore attivo"
(msg.upper(), #rendi maiuscola

 msg.replace("attivo","offline")) #sostituzione
# Out:
# ('SENSORE ATTIVO', 'sensore offline')

# %% [markdown]
# # Dizionario

# %%
device = {"id": "A-1","location":"Room1"}

# %% [markdown]
# # Liste di dizionari

# %%
sensori = [{"id":"S1","Titino":"meter"},{"id":"S2", "tipo":"battery"}]
sensori[1]
# Out:
# {'id': 'S2', 'tipo': 'battery'}

# %% [markdown]
# # Dizionari annidati

# %%
info = {
    "sensor":
        {"details":
             {"site":"B1", "zone":"West"}
         }
}
info["sensor"]["details"]["zone"] #accesso ad aree annidate settore per settore
# Out:
# 'West'

# %% [markdown]
# # Condizioni

# %%
potenza = 50
"alto" if potenza > 40 else "normale"  # puoi mettere anche prima la condizione vera, op ternario
# Out:
# 'alto'

# %%
x = 30
if x > 20:
    print("alto")
elif x > 40:
    print("normale")
else: print("basso")
# Out:
# alto

# %% [markdown]
# # For
